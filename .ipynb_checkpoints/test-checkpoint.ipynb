# %%
from dataset import *
from gpr import *
from train import *

# %%
# %cd /Users/oq7884/Documents/for_Danila/ace_gpr_atomwise
# Out:
# /Users/oq7884/Documents/for_Danila/ace_gpr_atomwise

# %%
dataset = ACE_Dataset(
    target_y="TOTEN",
    directory="../seminar/Random_9layers",
    max_order=2,
)
# Out:
# 100%|██████████| 250/250 [00:07<00:00, 35.48it/s]

# %%
train_dataset, valid_dataset = train_valid_split(dataset,
                                                 train_fraction=0.8,
                                                 seed=24153
                                                 )

train_x, train_y = get_tensors_from_subset(train_dataset)
valid_x, valid_y = get_tensors_from_subset(valid_dataset)

# %%
torch.set_default_dtype(torch.float64)

device = torch.device("cpu")
dtype = torch.float64

atom_dim = train_x[0].shape[1]

likelihood = gpytorch.likelihoods.GaussianLikelihood().to(device=device, dtype=dtype)

model = AtomicSumExactGP(
    n_train=len(train_x),
    train_y=train_y,
    likelihood=likelihood,
    atom_dim=atom_dim,
).to(device=device, dtype=dtype)

model.covar_module.set_train_structures(
    train_x,
    device=device,
    dtype=dtype,
)

model.covar_module.atom_kernel.base_kernel.lengthscale = torch.ones(
    atom_dim,
    device=device,
    dtype=dtype,
)

model.covar_module.atom_kernel.outputscale = torch.tensor(
    1.0,
    device=device,
    dtype=dtype,
)

likelihood.noise = torch.tensor(
    1e-2,
    device=device,
    dtype=dtype,
)

n_atoms_train = torch.tensor(
    [x.shape[0] for x in train_x],
    dtype=dtype,
    device=device,
)

model.mean_module.constant.data = (train_y / n_atoms_train).mean()

# %%
n_epoch = 30 # <- hyperparameter

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=5e-1)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=0.5,
    patience=100
)

# %%
logs, best_mae_valid = train(
    train_x=train_x,
    train_y=train_y,
    valid_x=valid_x,
    valid_y=valid_y,
    optimizer=optimizer,
    scheduler=scheduler,
    model=model,
    n_epochs = n_epoch,
    device = device,
    metadata = {"system": "Pt-Pd slab",
                "dataset_size": len(train_x),
                "target_y": "TOTEN",
                },
)
# Out:
# /opt/anaconda3/envs/ace_gpr/lib/python3.12/site-packages/gpytorch/models/exact_gp.py:299: GPInputWarning: The input matches the stored training data. Did you forget to call model.train()?
#   warnings.warn(
# Iter 1/300 Loss: 3.437021 MAE train: 0.000365 MAE valid: 2.931222 best MAE valid: 2.931222 noise: 0.006116 lr: 5.000e-01
# Iter 2/300 Loss: 4.046942 MAE train: 0.000069 MAE valid: 1.004212 best MAE valid: 1.004212 noise: 0.003754 lr: 5.000e-01
# Iter 3/300 Loss: 3.126480 MAE train: 0.000045 MAE valid: 0.705799 best MAE valid: 0.705799 noise: 0.002319 lr: 5.000e-01
# Iter 4/300 Loss: 3.051277 MAE train: 0.000045 MAE valid: 0.849610 best MAE valid: 0.705799 noise: 0.001448 lr: 5.000e-01
# Iter 5/300 Loss: 3.005835 MAE train: 0.000044 MAE valid: 0.904732 best MAE valid: 0.705799 noise: 0.000919 lr: 5.000e-01
# Iter 6/300 Loss: 2.904177 MAE train: 0.000042 MAE valid: 0.809816 best MAE valid: 0.705799 noise: 0.000599 lr: 5.000e-01
# Iter 7/300 Loss: 2.750972 MAE train: 0.000040 MAE valid: 0.692881 best MAE valid: 0.692881 noise: 0.000405 lr: 5.000e-01
# Iter 8/300 Loss: 2.558617 MAE train: 0.000040 MAE valid: 0.559891 best MAE valid: 0.559891 noise: 0.000287 lr: 5.000e-01
# Iter 9/300 Loss: 2.335958 MAE train: 0.000042 MAE valid: 0.428084 best MAE valid: 0.428084 noise: 0.000216 lr: 5.000e-01
# Iter 10/300 Loss: 2.087908 MAE train: 0.000047 MAE valid: 0.309811 best MAE valid: 0.309811 noise: 0.000172 lr: 5.000e-01
# Iter 11/300 Loss: 1.816454 MAE train: 0.000055 MAE valid: 0.215181 best MAE valid: 0.215181 noise: 0.000146 lr: 5.000e-01
# Iter 12/300 Loss: 1.521907 MAE train: 0.000070 MAE valid: 0.145954 best MAE valid: 0.145954 noise: 0.000130 lr: 5.000e-01
# Iter 13/300 Loss: 1.205414 MAE train: 0.000095 MAE valid: 0.100648 best MAE valid: 0.100648 noise: 0.000120 lr: 5.000e-01
# Iter 14/300 Loss: 0.874844 MAE train: 0.000135 MAE valid: 0.077725 best MAE valid: 0.077725 noise: 0.000113 lr: 5.000e-01
# Iter 15/300 Loss: 0.556679 MAE train: 0.000212 MAE valid: 0.074657 best MAE valid: 0.074657 noise: 0.000109 lr: 5.000e-01
# Iter 16/300 Loss: 0.310710 MAE train: 0.000362 MAE valid: 0.077186 best MAE valid: 0.074657 noise: 0.000107 lr: 5.000e-01
# Iter 17/300 Loss: 0.210557 MAE train: 0.000604 MAE valid: 0.073707 best MAE valid: 0.073707 noise: 0.000105 lr: 5.000e-01
# Iter 18/300 Loss: 0.199246 MAE train: 0.000867 MAE valid: 0.056626 best MAE valid: 0.056626 noise: 0.000103 lr: 5.000e-01
# Iter 19/300 Loss: 0.041715 MAE train: 0.001103 MAE valid: 0.042895 best MAE valid: 0.042895 noise: 0.000103 lr: 5.000e-01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 logs, best_mae_valid = train(
#       2     train_x=train_x,
#       3     train_y=train_y,
#       4     valid_x=valid_x,
#       5     valid_y=valid_y,
#       6     optimizer=optimizer,
#       7     scheduler=scheduler,
#       8     model=model,
#       9     n_epochs = n_epoch,
#      10     device = device,
#      11     metadata = {"system": "Pt-Pd slab",
#      12                 "dataset_size": len(train_x),
#      13                 "target_y": "TOTEN",
#      14                 },
#      15 )
#
# File ~/Documents/for_Danila/ace_gpr_atomwise/train.py:98, in train(train_x, train_y, valid_x, valid_y, optimizer, scheduler, model, n_epochs, device, checkpoint_path, metadata)
#      95 model.likelihood.eval()
#      97 with torch.no_grad(), gpytorch.settings.fast_pred_var():
# ---> 98     pred_train = model(train_ids).mean
#     100 #     model.covar_module.set_query_structures(valid_x)
#     101
#     102 #     valid_ids = torch.arange(
#    (...)    110
#     111 #     model.covar_module.clear_query_structures()
#     113     with model.covar_module.register_query_structures(valid_x) as valid_ids:
#
# File /opt/anaconda3/envs/ace_gpr/lib/python3.12/site-packages/gpytorch/models/exact_gp.py:322, in ExactGP.__call__(self, *args, **kwargs)
#     308     # Create the prediction strategy for
#     309     self.prediction_strategy = prediction_strategy(
#     310         train_inputs=train_inputs,
#     311         train_prior_dist=train_output,
#     312         train_labels=self.train_targets,
#     313         likelihood=self.likelihood,
#     314     )
#     315 (
#     316     test_mean,
#     317     test_test_covar,
#     318     test_train_covar,
#     319     batch_shape,
#     320     test_shape,
#     321     posterior_class,
# --> 322 ) = self._get_test_prior_mean_and_covariances(train_inputs=train_inputs, test_inputs=inputs, **kwargs)
#     323 # Make the prediction
#     324 with settings.cg_tolerance(settings.eval_cg_tolerance.value()):
#
# File /opt/anaconda3/envs/ace_gpr/lib/python3.12/site-packages/gpytorch/models/exact_gp.py:427, in ExactGP._get_test_prior_mean_and_covariances(self, train_inputs, test_inputs, **kwargs)
#     422 # Extract test covariances. Slicing is lazy; K(train, train) is never computed.
#     423 # evaluate_kernel() converts to the linear operator type needed by prediction.
#     424 # NOTE: We must slice row and column indices together (not sequentially) for
#     425 # compatibility with BlockInterleavedLinearOperator used in multitask GPs.
#     426 test_test_covar = joint_covar[..., num_train:, num_train:].evaluate_kernel()
# --> 427 test_train_covar = joint_covar[..., num_train:, :num_train].evaluate_kernel()
#     429 posterior_class = full_output.__class__
#     430 return (test_mean, test_test_covar, test_train_covar, batch_shape, test_shape, posterior_class)
#
# File /opt/anaconda3/envs/ace_gpr/lib/python3.12/site-packages/gpytorch/utils/memoize.py:61, in _cached.<locals>.g(self, *args, **kwargs)
#      59 kwargs_pkl = pickle.dumps(kwargs)
#      60 if not _is_in_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl):
# ---> 61     return _add_to_cache(self, cache_name, method(self, *args, **kwargs), *args, kwargs_pkl=kwargs_pkl)
#      62 return _get_from_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl)
#
# File /opt/anaconda3/envs/ace_gpr/lib/python3.12/site-packages/gpytorch/lazy/lazy_evaluated_kernel_tensor.py:27, in recall_grad_state.<locals>.wrapped(self, *args, **kwargs)
#      24 @functools.wraps(method)
#      25 def wrapped(self, *args, **kwargs):
#      26     with torch.set_grad_enabled(self._is_grad_enabled):
# ---> 27         output = method(self, *args, **kwargs)
#      28     return output
#
# File /opt/anaconda3/envs/ace_gpr/lib/python3.12/site-packages/gpytorch/lazy/lazy_evaluated_kernel_tensor.py:355, in LazyEvaluatedKernelTensor.evaluate_kernel(self)
#     353     temp_active_dims = self.kernel.active_dims
#     354     self.kernel.active_dims = None
# --> 355     res = self.kernel(
#     356         x1,
#     357         x2,
#     358         diag=False,
#     359         last_dim_is_batch=self.last_dim_is_batch,
#     360         **self.params,
#     361     )
#     362     self.kernel.active_dims = temp_active_dims
#     364 # Check the size of the output
#
# File /opt/anaconda3/envs/ace_gpr/lib/python3.12/site-packages/gpytorch/kernels/kernel.py:533, in Kernel.__call__(self, x1, x2, diag, last_dim_is_batch, **params)
#     531     res = LazyEvaluatedKernelTensor(x1_, x2_, kernel=self, last_dim_is_batch=last_dim_is_batch, **params)
#     532 else:
# --> 533     res = to_linear_operator(super().__call__(x1_, x2_, last_dim_is_batch=last_dim_is_batch, **params))
#     534 return res
#
# File /opt/anaconda3/envs/ace_gpr/lib/python3.12/site-packages/gpytorch/module.py:83, in Module.__call__(self, *inputs, **kwargs)
#      82 def __call__(self, *inputs, **kwargs) -> Tensor | Distribution | LinearOperator:
# ---> 83     outputs = self.forward(*inputs, **kwargs)
#      84     if isinstance(outputs, list):
#      85         return [_validate_module_outputs(output) for output in outputs]
#
# File ~/Documents/for_Danila/ace_gpr_atomwise/gpr.py:114, in AtomicSumLookupKernel.forward(self, x1, x2, diag, **params)
#     111 structures_1 = self._structures_from_ids(x1)
#     112 structures_2 = self._structures_from_ids(x2)
# --> 114 K = atomic_sum_kernel_dense(
#     115     structures_1,
#     116     structures_2,
#     117     self.atom_kernel,
#     118 )
#     120 if diag:
#     121     return torch.diagonal(K)
#
# File ~/Documents/for_Danila/ace_gpr_atomwise/gpr.py:39, in atomic_sum_kernel_dense(structures_1, structures_2, atom_kernel)
#      37 for i, X1 in enumerate(structures_1):
#      38     for j, X2 in enumerate(structures_2):
# ---> 39         K_atoms = atom_kernel(X1, X2).to_dense()
#      40         K[i, j] = K_atoms.sum()
#      42 return K
#
# File /opt/anaconda3/envs/ace_gpr/lib/python3.12/site-packages/gpytorch/kernels/kernel.py:533, in Kernel.__call__(self, x1, x2, diag, last_dim_is_batch, **params)
#     531     res = LazyEvaluatedKernelTensor(x1_, x2_, kernel=self, last_dim_is_batch=last_dim_is_batch, **params)
#     532 else:
# --> 533     res = to_linear_operator(super().__call__(x1_, x2_, last_dim_is_batch=last_dim_is_batch, **params))
#     534 return res
#
# File /opt/anaconda3/envs/ace_gpr/lib/python3.12/site-packages/gpytorch/module.py:83, in Module.__call__(self, *inputs, **kwargs)
#      82 def __call__(self, *inputs, **kwargs) -> Tensor | Distribution | LinearOperator:
# ---> 83     outputs = self.forward(*inputs, **kwargs)
#      84     if isinstance(outputs, list):
#      85         return [_validate_module_outputs(output) for output in outputs]
#
# File /opt/anaconda3/envs/ace_gpr/lib/python3.12/site-packages/gpytorch/kernels/scale_kernel.py:109, in ScaleKernel.forward(self, x1, x2, last_dim_is_batch, diag, **params)
#     108 def forward(self, x1, x2, last_dim_is_batch=False, diag=False, **params):
# --> 109     orig_output = self.base_kernel.forward(x1, x2, diag=diag, last_dim_is_batch=last_dim_is_batch, **params)
#     110     outputscales = self.outputscale
#     111     if last_dim_is_batch:
#
# File /opt/anaconda3/envs/ace_gpr/lib/python3.12/site-packages/gpytorch/kernels/rbf_kernel.py:79, in RBFKernel.forward(self, x1, x2, diag, **params)
#      77     x1_ = x1.div(self.lengthscale)
#      78     x2_ = x2.div(self.lengthscale)
# ---> 79     return postprocess_rbf(self.covar_dist(x1_, x2_, square_dist=True, diag=diag, **params))
#      80 return RBFCovariance.apply(
#      81     x1,
#      82     x2,
#      83     self.lengthscale,
#      84     lambda x1, x2: self.covar_dist(x1, x2, square_dist=True, diag=False, **params),
#      85 )
#
# File /opt/anaconda3/envs/ace_gpr/lib/python3.12/site-packages/gpytorch/kernels/rbf_kernel.py:11, in postprocess_rbf(dist_mat)
#      10 def postprocess_rbf(dist_mat):
# ---> 11     return dist_mat.div_(-2).exp_()
#
# KeyboardInterrupt:

# %%
checkpoint = torch.load("best_gpr_model.pt", map_location=device)

model.load_state_dict(checkpoint["model_state_dict"])
model.likelihood.load_state_dict(checkpoint["likelihood_state_dict"])
# Out:
# GaussianLikelihood(
#   (noise_covar): HomoskedasticNoise(
#     (raw_noise_constraint): GreaterThan(1.000E-04)
#   )
# )

# %%
model.eval()
likelihood.eval()

with model.covar_module.register_query_structures(valid_x) as test_ids:
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        pred = likelihood(model(test_ids))

mean = pred.mean
std = pred.stddev

print("mean =", mean)
print("std  =", std)
# Out:
# mean = tensor([-133.5703, -152.3707, -152.4365, -140.9130, -139.6278, -149.8167,
#         -205.1605, -156.6535, -197.5543, -197.5432, -209.1724, -203.0195,
#         -142.3437, -170.5762, -131.2590, -167.6129, -168.6725, -208.1124,
#         -139.7425, -203.8740, -181.8692, -204.7962, -145.5388, -166.5453,
#         -142.9903, -191.7029, -179.4519, -163.8882, -135.9608, -197.2977,
#         -139.2699, -204.6173, -163.4505, -181.2568, -157.4583, -151.8757,
#         -205.0090, -150.6406, -192.6838, -195.4378, -145.4862, -207.0361,
#         -153.8022, -161.9765, -190.5955, -138.4013, -141.7100, -144.1619,
#         -148.7278, -196.1987])
# std  = tensor([0.0300, 0.0907, 0.0600, 0.0569, 0.0496, 0.0823, 0.0230, 0.1359, 0.0577,
#         0.0498, 0.0130, 0.0347, 0.0769, 0.1116, 0.0215, 0.1606, 0.1198, 0.0149,
#         0.0436, 0.0467, 0.1041, 0.0280, 0.0780, 0.1164, 0.0661, 0.0645, 0.0968,
#         0.0840, 0.0465, 0.0433, 0.0877, 0.0392, 0.0927, 0.0826, 0.0931, 0.1236,
#         0.0261, 0.0844, 0.0601, 0.0718, 0.0539, 0.0212, 0.0709, 0.1025, 0.0874,
#         0.0719, 0.0890, 0.0758, 0.0733, 0.0581])

# %%
(valid_y - mean)
# Out:
# tensor([ 0.0363, -0.1148, -0.0170, -0.0199,  0.0309,  0.0749,  0.0177, -0.2614,
#          0.0642, -0.0021, -0.0056,  0.0326, -0.0028,  0.0514, -0.0013, -0.0676,
#          0.0511, -0.0064, -0.0427, -0.0089, -0.0824,  0.0076,  0.0197,  0.0832,
#          0.0177, -0.0250,  0.0048,  0.0248, -0.0083, -0.0251,  0.0850,  0.0158,
#         -0.0301,  0.0295,  0.0265,  0.0664, -0.0133,  0.0826, -0.0358, -0.0283,
#          0.0145,  0.0169,  0.0166, -0.0008,  0.0531, -0.1140, -0.1327, -0.0941,
#         -0.0390, -0.0418])

# %% [markdown]
# # Supercell test

# %%
from ase.build import make_supercell

matrix = [[3,0,0],[0,3,0],[0,0,1]]

supercell = [torch.Tensor(Cluster_Expansion(make_supercell(atoms[i], matrix),
                            shells=shells,
                            max_order=3,
                            atom_indices=None
                           ).descriptor) for i in tqdm(range(len(atoms)))]
# Out:
# 100%|██████████| 20/20 [01:31<00:00,  4.59s/it]

# %%
model.eval()
likelihood.eval()

with model.covar_module.register_query_structures(supercell) as test_ids:
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        pred = likelihood(model(test_ids))

mean = pred.mean
std = pred.stddev

print("mean =", mean)
print("std  =", std)
# Out:
# mean = tensor([-1403.1064, -1525.4287, -1333.9101, -1410.1130, -1317.3994, -1734.3997,
#         -1192.0357, -1650.5030, -1412.2342, -1526.5610, -1715.8978, -1434.6880,
#         -1426.0491, -1199.9771, -1863.1740, -1794.5319, -1881.0557, -1338.9011,
#         -1734.4760, -1574.7308])
# std  = tensor([0.1350, 0.1350, 0.1350, 0.1350, 0.1350, 0.1350, 0.1350, 0.1350, 0.1350,
#         0.1350, 0.1350, 0.1350, 0.1350, 0.1350, 0.1350, 0.1350, 0.1350, 0.1350,
#         0.1350, 0.1350])

# %%
y*9
# Out:
# tensor([-1403.1065, -1525.4287, -1333.9098, -1410.1130, -1317.3997, -1734.3998,
#         -1192.0344, -1650.5032, -1412.2341, -1526.5611, -1715.8975, -1434.6881,
#         -1426.0490, -1199.9780, -1863.1733, -1794.5322, -1881.0564, -1338.9008,
#         -1734.4762, -1574.7307])

# %% [markdown]
# # Validation
